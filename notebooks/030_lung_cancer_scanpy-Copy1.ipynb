# %%
import glob
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import scanpy.api as sc

# %matplotlib inline

# %%
results_file = '/home/olga/scratch/maca/lung_cancer/lung_cancer.h5ad'


sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80)  # low dpi (dots per inch) yields small inline figures
sc.logging.print_versions()
# Out:
# scanpy==1.3.2 anndata==0.6.11 numpy==1.15.3 scipy==1.1.0 pandas==0.23.4 scikit-learn==0.19.1 statsmodels==0.9.0 python-igraph==0.7.1 louvain==0.6.1

# %%
import anndata

# %%
adata = anndata.read(results_file)

# %%
sc.tl.draw_graph(adata)
# Out:
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).

# %%
sc.pl.draw_graph(adata, edges=True)
# Out:
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
