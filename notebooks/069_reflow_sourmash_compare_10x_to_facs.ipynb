# %%
import pandas as pd

import numpy as np

# %%
annotation_facs = pd.read_csv('/home/ubuntu/tabula-muris/00_data_ingest/18_global_annotation_csv/annotations_facs.csv')
print(annotation_facs.shape)
annotation_facs.head()
# Out:
# (44949, 24)
# /home/ubuntu/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Neurog3>0_raw Neurog3>0_scaled                   cell  \
# 0           NaN              NaN  A1.B000610.3_56_F.1.1
# 1           NaN              NaN  A1.B002764.3_38_F.1.1
# 2           NaN              NaN  A1.B002771.3_39_F.1.1
# 3           NaN              NaN   A1.D041914.3_8_M.1.1
# 4           NaN              NaN   A1.D042253.3_9_M.1.1
#
#        cell_ontology_class cell_ontology_id  cluster.ids  \
# 0             bladder cell       CL:1001319            5
# 1  bladder urothelial cell       CL:1001428            3
# 2             bladder cell       CL:1001319            5
# 3             bladder cell       CL:1001319            5
# 4             bladder cell       CL:1001319            2
#
#                    free_annotation mouse.id mouse.sex plate.barcode  \
# 0         Bladder mesenchymal cell   3_56_F         F       B000610
# 1  Luminal bladder epithelial cell   3_38_F         F       B002764
# 2         Bladder mesenchymal cell   3_39_F         F       B002771
# 3         Bladder mesenchymal cell    3_8_M         M       D041914
# 4         Bladder mesenchymal cell    3_9_M         M       D042253
#
#        ...       subsetC  subsetC_cluster.ids subsetD  subsetD_cluster.ids  \
# 0      ...           NaN                  NaN     NaN                  NaN
# 1      ...           NaN                  NaN     NaN                  NaN
# 2      ...           NaN                  NaN     NaN                  NaN
# 3      ...           NaN                  NaN     NaN                  NaN
# 4      ...           NaN                  NaN     NaN                  NaN
#
#   subsetE  subsetE_cluster.ids subtissue   tissue tissue_tSNE_1  tissue_tSNE_2
# 0     NaN                  NaN       NaN  Bladder     -7.182841     -10.895094
# 1     NaN                  NaN       NaN  Bladder      4.199059     -11.050240
# 2     NaN                  NaN       NaN  Bladder    -11.995435      -7.325534
# 3     NaN                  NaN       NaN  Bladder     -6.820022     -14.174246
# 4     NaN                  NaN       NaN  Bladder    -24.163538      -7.499349
#
# [5 rows x 24 columns]

# %%
annotation_facs['cell_id'] = annotation_facs['cell'].str.replace('.', '-')
annotation_facs.head()
# Out:
#   Neurog3>0_raw Neurog3>0_scaled                   cell  \
# 0           NaN              NaN  A1.B000610.3_56_F.1.1
# 1           NaN              NaN  A1.B002764.3_38_F.1.1
# 2           NaN              NaN  A1.B002771.3_39_F.1.1
# 3           NaN              NaN   A1.D041914.3_8_M.1.1
# 4           NaN              NaN   A1.D042253.3_9_M.1.1
#
#        cell_ontology_class cell_ontology_id  cluster.ids  \
# 0             bladder cell       CL:1001319            5
# 1  bladder urothelial cell       CL:1001428            3
# 2             bladder cell       CL:1001319            5
# 3             bladder cell       CL:1001319            5
# 4             bladder cell       CL:1001319            2
#
#                    free_annotation mouse.id mouse.sex plate.barcode  \
# 0         Bladder mesenchymal cell   3_56_F         F       B000610
# 1  Luminal bladder epithelial cell   3_38_F         F       B002764
# 2         Bladder mesenchymal cell   3_39_F         F       B002771
# 3         Bladder mesenchymal cell    3_8_M         M       D041914
# 4         Bladder mesenchymal cell    3_9_M         M       D042253
#
#            ...           subsetC_cluster.ids  subsetD subsetD_cluster.ids  \
# 0          ...                           NaN      NaN                 NaN
# 1          ...                           NaN      NaN                 NaN
# 2          ...                           NaN      NaN                 NaN
# 3          ...                           NaN      NaN                 NaN
# 4          ...                           NaN      NaN                 NaN
#
#    subsetE subsetE_cluster.ids  subtissue   tissue  tissue_tSNE_1  \
# 0      NaN                 NaN        NaN  Bladder      -7.182841
# 1      NaN                 NaN        NaN  Bladder       4.199059
# 2      NaN                 NaN        NaN  Bladder     -11.995435
# 3      NaN                 NaN        NaN  Bladder      -6.820022
# 4      NaN                 NaN        NaN  Bladder     -24.163538
#
#   tissue_tSNE_2                cell_id
# 0    -10.895094  A1-B000610-3_56_F-1-1
# 1    -11.050240  A1-B002764-3_38_F-1-1
# 2     -7.325534  A1-B002771-3_39_F-1-1
# 3    -14.174246   A1-D041914-3_8_M-1-1
# 4     -7.499349   A1-D042253-3_9_M-1-1
#
# [5 rows x 25 columns]

# %%
annotation_droplet = pd.read_csv('/home/ubuntu/tabula-muris/00_data_ingest/18_global_annotation_csv/annotations_droplet.csv')
print(annotation_droplet.shape)
annotation_droplet.head()
# Out:
# (55656, 20)
# /home/ubuntu/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                         cell  cell_ontology_class cell_ontology_id   channel  \
# 0  10X_P7_8_AAACGGGAGGATATAC         myeloid cell       CL:0000763  10X_P7_8
# 1  10X_P7_8_AAACGGGTCTCGTATT  alveolar macrophage       CL:0000583  10X_P7_8
# 2  10X_P7_8_AAAGATGCAGATCTGT               B cell       CL:0000236  10X_P7_8
# 3  10X_P7_8_AAATGCCAGATAGTCA  natural killer cell       CL:0000623  10X_P7_8
# 4  10X_P7_8_AAATGCCCAAACTGCT               T cell       CL:0000084  10X_P7_8
#
#    cluster.ids                              free_annotation mouse.id  \
# 0           20  dendritic cells and interstital macrophages   3-F-56
# 1            5                                          NaN   3-F-56
# 2           12                                          NaN   3-F-56
# 3            7                                          NaN   3-F-56
# 4           21                                          NaN   3-F-56
#
#   mouse.sex subsetA  subsetA_cluster.ids subsetB  subsetB_cluster.ids subsetC  \
# 0         F     NaN                  NaN     NaN                  NaN     NaN
# 1         F     NaN                  NaN     NaN                  NaN     NaN
# 2         F     NaN                  NaN     NaN                  NaN     NaN
# 3         F     NaN                  NaN     NaN                  NaN     NaN
# 4         F     NaN                  NaN     NaN                  NaN     NaN
#
#    subsetC_cluster.ids subsetD  subsetD_cluster.ids subtissue tissue  \
# 0                  NaN     NaN                  NaN       NaN   Lung
# 1                  NaN     NaN                  NaN       NaN   Lung
# 2                  NaN     NaN                  NaN       NaN   Lung
# 3                  NaN     NaN                  NaN       NaN   Lung
# 4                  NaN     NaN                  NaN       NaN   Lung
#
#    tissue_tSNE_1  tissue_tSNE_2
# 0      17.024721     -32.902836
# 1      25.160619      25.066566
# 2       1.740567      46.488878
# 3     -31.647934      -2.208061
# 4     -37.281266      -5.619565

# %% [markdown]
# We're using the `10X_P4_3` channel for bladder and `10X_P7_8` channel for lung.

# %%
bladder_channel = "10X_P4_3"

annotation_droplet.query('channel == @bladder_channel').head()
# Out:
#                             cell      cell_ontology_class cell_ontology_id  \
# 38084  10X_P4_3_AAAGTAGAGATGCCAG             bladder cell       CL:1001319
# 38085  10X_P4_3_AACCGCGTCCAACCAA             bladder cell       CL:1001319
# 38086  10X_P4_3_AACTCCCGTCGGGTCT             bladder cell       CL:1001319
# 38087  10X_P4_3_AACTCTTAGTTGCAGG  bladder urothelial cell       CL:1001428
# 38088  10X_P4_3_AACTCTTTCATAACCG             bladder cell       CL:1001319
#
#         channel  cluster.ids                  free_annotation mouse.id  \
# 38084  10X_P4_3            0         Bladder mesenchymal cell    3-M-8
# 38085  10X_P4_3            2         Bladder mesenchymal cell    3-M-8
# 38086  10X_P4_3            5         Bladder mesenchymal cell    3-M-8
# 38087  10X_P4_3            3  Luminal bladder epithelial cell    3-M-8
# 38088  10X_P4_3            2         Bladder mesenchymal cell    3-M-8
#
#       mouse.sex subsetA  subsetA_cluster.ids subsetB  subsetB_cluster.ids  \
# 38084         M     NaN                  NaN     NaN                  NaN
# 38085         M     NaN                  NaN     NaN                  NaN
# 38086         M     NaN                  NaN     NaN                  NaN
# 38087         M     NaN                  NaN     NaN                  NaN
# 38088         M     NaN                  NaN     NaN                  NaN
#
#       subsetC  subsetC_cluster.ids subsetD  subsetD_cluster.ids subtissue  \
# 38084     NaN                  NaN     NaN                  NaN       NaN
# 38085     NaN                  NaN     NaN                  NaN       NaN
# 38086     NaN                  NaN     NaN                  NaN       NaN
# 38087     NaN                  NaN     NaN                  NaN       NaN
# 38088     NaN                  NaN     NaN                  NaN       NaN
#
#         tissue  tissue_tSNE_1  tissue_tSNE_2
# 38084  Bladder     -28.034252     -13.407488
# 38085  Bladder     -15.890827       7.453387
# 38086  Bladder     -11.131739       8.426802
# 38087  Bladder      21.559201       6.817286
# 38088  Bladder      -5.939946      19.630456

# %%
lung_channel = "10X_P7_8"

annotation_droplet.query('channel == @lung_channel').head()
# Out:
#                         cell  cell_ontology_class cell_ontology_id   channel  \
# 0  10X_P7_8_AAACGGGAGGATATAC         myeloid cell       CL:0000763  10X_P7_8
# 1  10X_P7_8_AAACGGGTCTCGTATT  alveolar macrophage       CL:0000583  10X_P7_8
# 2  10X_P7_8_AAAGATGCAGATCTGT               B cell       CL:0000236  10X_P7_8
# 3  10X_P7_8_AAATGCCAGATAGTCA  natural killer cell       CL:0000623  10X_P7_8
# 4  10X_P7_8_AAATGCCCAAACTGCT               T cell       CL:0000084  10X_P7_8
#
#    cluster.ids                              free_annotation mouse.id  \
# 0           20  dendritic cells and interstital macrophages   3-F-56
# 1            5                                          NaN   3-F-56
# 2           12                                          NaN   3-F-56
# 3            7                                          NaN   3-F-56
# 4           21                                          NaN   3-F-56
#
#   mouse.sex subsetA  subsetA_cluster.ids subsetB  subsetB_cluster.ids subsetC  \
# 0         F     NaN                  NaN     NaN                  NaN     NaN
# 1         F     NaN                  NaN     NaN                  NaN     NaN
# 2         F     NaN                  NaN     NaN                  NaN     NaN
# 3         F     NaN                  NaN     NaN                  NaN     NaN
# 4         F     NaN                  NaN     NaN                  NaN     NaN
#
#    subsetC_cluster.ids subsetD  subsetD_cluster.ids subtissue tissue  \
# 0                  NaN     NaN                  NaN       NaN   Lung
# 1                  NaN     NaN                  NaN       NaN   Lung
# 2                  NaN     NaN                  NaN       NaN   Lung
# 3                  NaN     NaN                  NaN       NaN   Lung
# 4                  NaN     NaN                  NaN       NaN   Lung
#
#    tissue_tSNE_1  tissue_tSNE_2
# 0      17.024721     -32.902836
# 1      25.160619      25.066566
# 2       1.740567      46.488878
# 3     -31.647934      -2.208061
# 4     -37.281266      -5.619565

# %%
random_bladder = annotation_facs.query('tissue == "Bladder"').sample(n=150, random_state=0)
print(random_bladder.shape)
random_bladder.head()
# Out:
# (150, 25)
#      Neurog3>0_raw Neurog3>0_scaled                      cell  \
# 1026           NaN              NaN   L4.MAA000487.3_10_M.1.1
# 649            NaN              NaN  H18.MAA000487.3_10_M.1.1
# 579            NaN              NaN     G22.D042253.3_9_M.1.1
# 31             NaN              NaN  A14.MAA000487.3_10_M.1.1
# 254            NaN              NaN      C6.D042253.3_9_M.1.1
#
#           cell_ontology_class cell_ontology_id  cluster.ids  \
# 1026             bladder cell       CL:1001319            0
# 649   bladder urothelial cell       CL:1001428            6
# 579   bladder urothelial cell       CL:1001428            1
# 31    bladder urothelial cell       CL:1001428            1
# 254              bladder cell       CL:1001319            2
#
#                       free_annotation mouse.id mouse.sex plate.barcode  \
# 1026         Bladder mesenchymal cell   3_10_M         M     MAA000487
# 649     Basal bladder epithelial cell   3_10_M         M     MAA000487
# 579   Luminal bladder epithelial cell    3_9_M         M       D042253
# 31    Luminal bladder epithelial cell   3_10_M         M     MAA000487
# 254          Bladder mesenchymal cell    3_9_M         M       D042253
#
#                 ...            subsetC_cluster.ids  subsetD  \
# 1026            ...                            NaN      NaN
# 649             ...                            NaN      NaN
# 579             ...                            NaN      NaN
# 31              ...                            NaN      NaN
# 254             ...                            NaN      NaN
#
#      subsetD_cluster.ids  subsetE subsetE_cluster.ids  subtissue   tissue  \
# 1026                 NaN      NaN                 NaN        NaN  Bladder
# 649                  NaN      NaN                 NaN        NaN  Bladder
# 579                  NaN      NaN                 NaN        NaN  Bladder
# 31                   NaN      NaN                 NaN        NaN  Bladder
# 254                  NaN      NaN                 NaN        NaN  Bladder
#
#       tissue_tSNE_1 tissue_tSNE_2                   cell_id
# 1026      -3.848008    -31.627362   L4-MAA000487-3_10_M-1-1
# 649       -2.330604      8.687074  H18-MAA000487-3_10_M-1-1
# 579       18.170798      4.763290     G22-D042253-3_9_M-1-1
# 31         5.698090      8.262338  A14-MAA000487-3_10_M-1-1
# 254      -28.777886     -0.332360      C6-D042253-3_9_M-1-1
#
# [5 rows x 25 columns]

# %%
facs_prefix = 's3://olgabot-maca/facs/sourmash_compute_all/'

# %%
bladder_facs = facs_prefix + random_bladder['cell_id'] + '.sig'
bladder_facs = bladder_facs.tolist()
bladder_facs[:5]
# Out:
# ['s3://olgabot-maca/facs/sourmash_compute_all/L4-MAA000487-3_10_M-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/H18-MAA000487-3_10_M-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/G22-D042253-3_9_M-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/A14-MAA000487-3_10_M-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/C6-D042253-3_9_M-1-1.sig']

# %%
random_lung = annotation_facs.query('tissue == "Lung"').sample(n=600, random_state=0)
print(random_lung.shape)
random_lung.head()
# Out:
# (600, 25)
#       Neurog3>0_raw Neurog3>0_scaled                      cell  \
# 14557           NaN              NaN   K7.MAA001889.3_38_F.1.1
# 13412           NaN              NaN   A10.MAA000526.3_9_M.1.1
# 14152           NaN              NaN  H10.MAA001889.3_38_F.1.1
# 14727           NaN              NaN    M20.D043522.3_39_F.1.1
# 13879           NaN              NaN  E19.MAA001847.3_39_F.1.1
#
#            cell_ontology_class cell_ontology_id  cluster.ids  \
# 14557       classical monocyte       CL:0000860            7
# 13412             stromal cell       CL:0000499            2
# 14152  epithelial cell of lung       CL:0000082            5
# 14727       classical monocyte       CL:0000860            7
# 13879    lung endothelial cell       CL:1001567           18
#
#                                          free_annotation mouse.id mouse.sex  \
# 14557                                 invading monocytes   3_38_F         F
# 13412                                                NaN    3_9_M         M
# 14152  alveolar epithelial type 1 cells, alveolar epi...   3_38_F         F
# 14727                                 invading monocytes   3_39_F         F
# 13879                                                NaN   3_39_F         F
#
#       plate.barcode            ...            subsetC_cluster.ids  subsetD  \
# 14557     MAA001889            ...                            NaN      NaN
# 13412     MAA000526            ...                            NaN      NaN
# 14152     MAA001889            ...                            NaN      NaN
# 14727       D043522            ...                            NaN      NaN
# 13879     MAA001847            ...                            NaN      NaN
#
#       subsetD_cluster.ids  subsetE subsetE_cluster.ids  subtissue tissue  \
# 14557                 NaN      NaN                 NaN      EPCAM   Lung
# 13412                 NaN      NaN                 NaN        NaN   Lung
# 14152                 NaN      NaN                 NaN      EPCAM   Lung
# 14727                 NaN      NaN                 NaN  Endomucin   Lung
# 13879                 NaN      NaN                 NaN      EPCAM   Lung
#
#        tissue_tSNE_1 tissue_tSNE_2                   cell_id
# 14557      33.084813      3.938196   K7-MAA001889-3_38_F-1-1
# 13412     -21.346104    -20.762233   A10-MAA000526-3_9_M-1-1
# 14152      14.140883     27.086416  H10-MAA001889-3_38_F-1-1
# 14727      36.110107      0.751320    M20-D043522-3_39_F-1-1
# 13879      -5.749042     37.681019  E19-MAA001847-3_39_F-1-1
#
# [5 rows x 25 columns]

# %%
lung_facs = facs_prefix + random_lung['cell_id'] + '.sig'
lung_facs = lung_facs.tolist()
lung_facs[:5]
# Out:
# ['s3://olgabot-maca/facs/sourmash_compute_all/K7-MAA001889-3_38_F-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/A10-MAA000526-3_9_M-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/H10-MAA001889-3_38_F-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/M20-D043522-3_39_F-1-1.sig',
#  's3://olgabot-maca/facs/sourmash_compute_all/E19-MAA001847-3_39_F-1-1.sig']

# %%
lung_tenx = 's3://olgabot-maca/10x/10X_P7_8/scaled=1000_num_hashes=0/possorted_genome_bam.sig'
bladder_tenx = 's3://olgabot-maca/10x/10X_P4_3/scaled=1000_num_hashes=0/possorted_genome_bam.sig'

# %%
! aws s3 ls $lung_tenx
# Out:
# 2018-10-16 00:18:16  201970926 possorted_genome_bam.sig

# %%
bladder_signatures = '|'.join(bladder_facs + [bladder_tenx])
bladder_signatures[:200]
# Out:
# 's3://olgabot-maca/facs/sourmash_compute_all/L4-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/H18-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G22-D042253'

# %%
lung_signatures = '|'.join(lung_facs + [lung_tenx])
lung_signatures[:200]
# Out:
# 's3://olgabot-maca/facs/sourmash_compute_all/K7-MAA001889-3_38_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/A10-MAA000526-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/H10-MAA00188'

# %%
tenx_tissues = dict(Bladder=bladder_tenx, Lung=lung_tenx)
tenx_tissues["Bladder"]
# Out:
# 's3://olgabot-maca/10x/10X_P4_3/scaled=1000_num_hashes=0/possorted_genome_bam.sig'

# %%
facs_tissues = dict(Bladder='|'.join(bladder_facs), Lung='|'.join(lung_facs))
facs_tissues['Bladder'][:500]
# Out:
# 's3://olgabot-maca/facs/sourmash_compute_all/L4-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/H18-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G22-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/A14-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C6-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C17-B002771-3_39_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C1-B002771-3_39_F-1-1.sig|s3'

# %%
import itertools

ksize = 27
molecules = 'protein', 'dna'
ignore_abundances = True, False
tissues = 'Bladder', 'Lung'

data = itertools.product(molecules, ignore_abundances, tissues, tissues)
samples = pd.DataFrame(list(data), columns=['sequence_to_compare', 'ignore_abundance', 
                                      'tenx_tissue', 'facs_tissue'])
samples['ksize'] = ksize
print(samples.shape)
samples
# Out:
# (16, 5)
#    sequence_to_compare  ignore_abundance tenx_tissue facs_tissue  ksize
# 0              protein              True     Bladder     Bladder     27
# 1              protein              True     Bladder        Lung     27
# 2              protein              True        Lung     Bladder     27
# 3              protein              True        Lung        Lung     27
# 4              protein             False     Bladder     Bladder     27
# 5              protein             False     Bladder        Lung     27
# 6              protein             False        Lung     Bladder     27
# 7              protein             False        Lung        Lung     27
# 8                  dna              True     Bladder     Bladder     27
# 9                  dna              True     Bladder        Lung     27
# 10                 dna              True        Lung     Bladder     27
# 11                 dna              True        Lung        Lung     27
# 12                 dna             False     Bladder     Bladder     27
# 13                 dna             False     Bladder        Lung     27
# 14                 dna             False        Lung     Bladder     27
# 15                 dna             False        Lung        Lung     27

# %%
def make_signatures(row):
    tenx_signatures = tenx_tissues[row.tenx_tissue]
    facs_signatures = facs_tissues[row.facs_tissue]
    return '|'.join([tenx_signatures, facs_signatures])
    
samples['signatures'] = samples.apply(make_signatures, axis=1)
samples.head()
# Out:
#   sequence_to_compare  ignore_abundance tenx_tissue facs_tissue  ksize  \
# 0             protein              True     Bladder     Bladder     27
# 1             protein              True     Bladder        Lung     27
# 2             protein              True        Lung     Bladder     27
# 3             protein              True        Lung        Lung     27
# 4             protein             False     Bladder     Bladder     27
#
#                                           signatures
# 0  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 1  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 2  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 3  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 4  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...

# %%
def make_id(row):
    name = 'tenx={tenx_tissue}_facs={facs_tissue}_molecule={sequence_to_compare}_'\
        'ksize={ksize}_ignore_abundance={ignore_abundance}'.format(**row)
    return name

samples['id'] = samples.apply(make_id, axis=1)
samples.head()
# Out:
#   sequence_to_compare  ignore_abundance tenx_tissue facs_tissue  ksize  \
# 0             protein              True     Bladder     Bladder     27
# 1             protein              True     Bladder        Lung     27
# 2             protein              True        Lung     Bladder     27
# 3             protein              True        Lung        Lung     27
# 4             protein             False     Bladder     Bladder     27
#
#                                           signatures  \
# 0  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 1  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 2  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 3  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 4  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
#
#                                                   id  \
# 0  tenx=Bladder_facs=Bladder_molecule=protein_ksi...
# 1  tenx=Bladder_facs=Lung_molecule=protein_ksize=...
# 2  tenx=Lung_facs=Bladder_molecule=protein_ksize=...
# 3  tenx=Lung_facs=Lung_molecule=protein_ksize=27_...
# 4  tenx=Bladder_facs=Bladder_molecule=protein_ksi...
#
#                                               output
# 0  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 1  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 2  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 3  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 4  s3://olgabot-maca/10x_vs_facs/sourmash_compare...

# %%
output_prefix = 's3://olgabot-maca/10x_vs_facs/sourmash_compare/'

# %%
samples['output'] = output_prefix + samples['id'] + '.csv'
samples.head()
# Out:
#   sequence_to_compare  ignore_abundance tenx_tissue facs_tissue  ksize  \
# 0             protein              True     Bladder     Bladder     27
# 1             protein              True     Bladder        Lung     27
# 2             protein              True        Lung     Bladder     27
# 3             protein              True        Lung        Lung     27
# 4             protein             False     Bladder     Bladder     27
#
#                                           signatures  \
# 0  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 1  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# 2  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 3  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# 4  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
#
#                                                   id  \
# 0  tenx=Bladder_facs=Bladder_molecule=protein_ksi...
# 1  tenx=Bladder_facs=Lung_molecule=protein_ksize=...
# 2  tenx=Lung_facs=Bladder_molecule=protein_ksize=...
# 3  tenx=Lung_facs=Lung_molecule=protein_ksize=27_...
# 4  tenx=Bladder_facs=Bladder_molecule=protein_ksi...
#
#                                               output
# 0  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 1  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 2  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 3  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# 4  s3://olgabot-maca/10x_vs_facs/sourmash_compare...

# %%
samples_cleaned = samples.set_index("id")
samples_cleaned = samples_cleaned.drop(columns=['tenx_tissue', 'facs_tissue'])
samples_cleaned.head()
# Out:
#                                                    sequence_to_compare  \
# id
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...             protein
# tenx=Bladder_facs=Lung_molecule=protein_ksize=2...             protein
# tenx=Lung_facs=Bladder_molecule=protein_ksize=2...             protein
# tenx=Lung_facs=Lung_molecule=protein_ksize=27_i...             protein
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...             protein
#
#                                                     ignore_abundance  ksize  \
# id
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...              True     27
# tenx=Bladder_facs=Lung_molecule=protein_ksize=2...              True     27
# tenx=Lung_facs=Bladder_molecule=protein_ksize=2...              True     27
# tenx=Lung_facs=Lung_molecule=protein_ksize=27_i...              True     27
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...             False     27
#
#                                                                                            signatures  \
# id
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# tenx=Bladder_facs=Lung_molecule=protein_ksize=2...  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
# tenx=Lung_facs=Bladder_molecule=protein_ksize=2...  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# tenx=Lung_facs=Lung_molecule=protein_ksize=27_i...  s3://olgabot-maca/10x/10X_P7_8/scaled=1000_num...
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...  s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num...
#
#                                                                                                output
# id
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# tenx=Bladder_facs=Lung_molecule=protein_ksize=2...  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# tenx=Lung_facs=Bladder_molecule=protein_ksize=2...  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# tenx=Lung_facs=Lung_molecule=protein_ksize=27_i...  s3://olgabot-maca/10x_vs_facs/sourmash_compare...
# tenx=Bladder_facs=Bladder_molecule=protein_ksiz...  s3://olgabot-maca/10x_vs_facs/sourmash_compare...

# %%
import json

folder = '../sourmash/maca/10x_vs_facs'

! mkdir -p $folder
assert samples_cleaned.index.is_unique
samples_cleaned.to_csv(f'{folder}/samples.csv')

config = 	{
		"program": "../../../reflow/sourmash_compute_files.rf",
		"runs_file": "samples.csv"
	}

with open(f'{folder}/config.json', 'w') as f:
    json.dump(config, f)
    
! head -n 2 $folder/samples.csv $folder/config.json
# Out:
# ==> ../sourmash/maca/10x_vs_facs/samples.csv <==
# id,sequence_to_compare,ignore_abundance,ksize,signatures,output
# tenx=Bladder_facs=Bladder_molecule=protein_ksize=27_ignore_abundance=True,protein,True,27,s3://olgabot-maca/10x/10X_P4_3/scaled=1000_num_hashes=0/possorted_genome_bam.sig|s3://olgabot-maca/facs/sourmash_compute_all/L4-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/H18-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G22-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/A14-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C6-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C17-B002771-3_39_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C1-B002771-3_39_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/I6-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/F21-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/D8-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/J11-B002764-3_38_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/J5-B002764-3_38_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L10-B002771-3_39_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/I7-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/N3-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/B5-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P11-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L13-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/O17-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G21-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/K18-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/O14-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G3-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L14-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G9-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/H2-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L16-B002764-3_38_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L17-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/E6-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P4-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L5-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/D19-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/K1-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/K16-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L19-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P9-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/F15-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G2-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P15-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P15-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/I15-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P2-B000610-3_56_F-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/P16-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/M19-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C19-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/L22-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/A2-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/B11-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/O9-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/G9-D041914-3_8_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/E6-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/O2-MAA000487-3_10_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/A15-D042253-3_9_M-1-1.sig|s3://olgabot-maca/facs/sourmash_compute_all/C14-MAA000487-3_10_M-1-1.sig|s3://olgabot-ma ...
#
# ==> ../sourmash/maca/10x_vs_facs/config.json <==
# {"program": "../../../reflow/sourmash_compute_files.rf", "runs_file": "samples.csv"}
