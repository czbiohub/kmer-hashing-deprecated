# %%
import glob
from itertools import product
import itertools


from joblib import Parallel, delayed
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sourmash import signature as sig
from tqdm import tqdm

# %matplotlib inline

# %%
import common

figure_folder = common.get_figure_folder()
! mkdir -p $figure_folder
figure_folder
# Out:
# '../figures/082_analyze_bladder_kidney_spleen_facs_tf-idf'

# %% [markdown]
# ## Load the signatures

# %%
# %%time

import pickle
folder = '/home/olga/scratch/maca/facs/sourmash_compute_tissue_subset/'

pickle_filename = f'{folder}/siglist.pickle'

with open(pickle_filename, 'rb') as f:
    siglist_all = pickle.load(f)

# %%
len(siglist_all)
# Out:
# 1000

# %%
s = siglist_all[0]
s.name
# Out:
# <bound method SourmashSignature.name of SourmashSignature('A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue:NA|cell_ontology_class:bladder_urothelial_cell|free_annotation:Luminal_bladder_epithelial_cell', 2da2310b)>

# %%
for s in siglist_all[:10]:
    print('---')
    print(f's.minhash.ksize: {s.minhash.ksize}')
    print(f's.minhash.is_protein: {s.minhash.is_protein}')
# Out:
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False
# ---
# s.minhash.ksize: 21
# s.minhash.is_protein: False

# %%
# siglist_k21_dna_hash_abundances = [pd.Series(s.minhash.get_mins(with_abundance=True)) for s in siglist]
# siglist_k21_dna_hash_abundances[:5]

fig, ax = plt.subplots()
ax.set(xscale='log')
 
for s in siglist:
    sns.kdeplot(pd.Series(s.minhash.get_mins(with_abundance=True)))
# ax.legend()
# Out:
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
hashes = s.minhash.get_mins(with_abundance=True)

# %%
pd.Series(hashes).head()
# Out:
# 5185133228099     1
# 10809012144400    1
# 11183162483320    1
# 11329527245923    1
# 18288931836992    2
# dtype: int64

# %%
# unique_hashes = set([])

# num_hashes_per_i = pd.Series(index=range(len(siglist_k21_dna)))

# for i, s in enumerate(siglist_k21_dna):
#     unique_hashes.update(s.minhash.get_mins())
    
#     n = len(unique_hashes)
#     num_hashes_per_i[i] = n
    
# #     print(f'i: {i}\tNum hashes: {n}')


# num_hashes_per_i.plot()

# %%
# %%file idf.py

from collections import Counter
import math


def filter_idf(hashes, idf, mean_idf_per_cell):
    return set(x for x in hashes if idf[x] > mean_idf_per_cell)

def _get_single_cell_mean_idf(signature, idf):
    min_hashes = signature.minhash.get_mins()
    
    vsum = sum(idf[x] for x in min_hashes)
    mean_idf = vsum/len(min_hashes)
    return mean_idf


def get_mean_idf_per_cell(siglist, idf):
    idf_sums = sum(_get_single_cell_mean_idf(s, idf) for s in siglist)
    mean_idf = idf_sums/len(siglist)
    
    return mean_idf

def get_term_frequency(hash_abundance):
    """Convert raw term abundance to relative frequency in document"""
    total_counts = sum(hash_abundance.values())
    return {k: v/total_counts for k, v in hash_abundance.items()}

def get_document_frequency(siglist):
    document_frequency = Counter()
    for s in siglist:
        document_frequency.update(s.minhash.get_mins())
    return document_frequency

def get_inverse_document_frequency(siglist):
    
    # total number of documents
    N = len(siglist)
    document_frequency = get_document_frequency(siglist)
    inverse_document_frequency = {k: math.log(N/v) for k, v in document_frequency.items()}
    return inverse_document_frequency
# Out:
# Writing idf.py

# %%
term_frequency = idf.get_term_frequency(s.minhash.get_mins(with_abundance=True))

# %%
inverse_document_frequency = get_inverse_document_frequency(siglist)
inverse_document_frequency

# %%
document_frequency = get_document_frequency(siglist)
document_frequency
# Out:
# Counter({4319888920071: 1,
#          11897683056067: 163,
#          15688568034930: 14,
#          18288931836992: 468,
#          27514404317028: 2,
#          28774406637780: 2,
#          28801856705165: 51,
#          29695955487065: 1,
#          31178866345647: 1,
#          31925058964274: 89,
#          47806340697682: 1,
#          49151368282908: 1,
#          52850654120648: 1,
#          53953467848099: 2,
#          55757903243021: 19,
#          60312253707825: 2,
#          62659638291682: 1,
#          66241835422762: 1,
#          68153692112883: 4,
#          73882272905754: 1,
#          74570550004114: 1,
#          76820010456855: 1,
#          77444246978017: 1,
#          79012937136486: 16,
#          79156257812791: 1,
#          79567150580843: 258,
#          87249997581706: 1,
#          96935414578882: 1,
#          101062645010737: 1,
#          105471824470775: 1,
#          109299403491668: 38,
#          113644304926286: 1,
#          118640640850110: 220,
#          126361336751132: 1,
#          126759430880730: 16,
#          130397593504987: 1,
#          138660100354690: 140,
#          139331188510898: 2,
#          140535110285782: 1,
#          141951210497995: 1,
#          142878644328384: 10,
#          146855652536083: 4,
#          148808605713245: 10,
#          148930274038541: 533,
#          150953471857068: 5,
#          159134727925080: 7,
#          161171989561266: 11,
#          169342448466942: 1,
#          171428891559143: 1,
#          171794956858086: 677,
#          173027221775977: 1,
#          177993160608566: 183,
#          180107221799816: 26,
#          183893335313721: 1,
#          189423328062162: 197,
#          190320147003157: 98,
#          197536288412964: 1,
#          200441522625834: 320,
#          201694986629989: 403,
#          208457723782265: 1,
#          210414208122753: 43,
#          211887044195984: 109,
#          217064341792262: 2,
#          221889693420619: 1,
#          228764607696444: 1,
#          229522628579452: 1,
#          229879514868002: 427,
#          234007674252594: 163,
#          236513781591757: 1,
#          238810212816881: 68,
#          242550903510249: 230,
#          243982289941556: 17,
#          246122388300833: 1,
#          248744195150357: 103,
#          250174245870087: 6,
#          259408192654818: 1,
#          260930873129971: 380,
#          265270962234285: 3,
#          265986678994683: 1,
#          266852646332518: 45,
#          272490607578679: 1,
#          274740508403806: 6,
#          277094292981821: 16,
#          277299210129149: 3,
#          277483373899692: 179,
#          278621767828794: 84,
#          280348453985171: 1,
#          284228482373793: 6,
#          296409329051649: 1,
#          298617769812989: 215,
#          308016070973804: 151,
#          308535032426400: 1,
#          311087267245435: 1,
#          311486905220001: 13,
#          313364357106326: 384,
#          773087006754267: 1,
#          773257973278598: 11,
#          788757032491877: 1,
#          789221247419341: 3,
#          790330283259107: 283,
#          794597856403115: 353,
#          802028096598027: 53,
#          809717029098059: 2,
#          812662900661843: 17,
#          812995517333277: 1,
#          815659616174872: 1,
#          818766435827652: 5,
#          819729369759045: 6,
#          822583654167470: 2,
#          823999364344753: 70,
#          824427196476496: 4,
#          827541603477938: 73,
#          833635882519663: 1,
#          835819991954234: 6,
#          837806455473043: 87,
#          846723351318774: 1,
#          849978368064157: 4,
#          855095691102234: 12,
#          858481542229341: 1,
#          860437213521678: 397,
#          860925580894101: 5,
#          864548047592117: 3,
#          864944117109758: 233,
#          865717145361750: 1,
#          866382481007412: 43,
#          867139457989801: 394,
#          867679297068238: 6,
#          869133106525770: 1,
#          882625890316629: 258,
#          886342190304074: 5,
#          892363136170294: 15,
#          898820996751006: 45,
#          902179660198159: 24,
#          908109471661532: 101,
#          934511326809131: 1,
#          936637619733676: 896,
#          937297519400782: 1,
#          937624453106451: 1000,
#          940854013098708: 1,
#          943543350514262: 37,
#          946773774623882: 1,
#          949898180694758: 18,
#          955126305176836: 9,
#          956129093250923: 1,
#          963560965772685: 1,
#          968596856444428: 159,
#          972599778615589: 1,
#          975618263025077: 25,
#          979209967471136: 109,
#          985487046007212: 1,
#          988532882058655: 116,
#          993363651091172: 6,
#          993512216498851: 20,
#          995044713118360: 16,
#          996353528178834: 439,
#          996671213888868: 35,
#          1000498746257009: 108,
#          1000930902146334: 1,
#          1003179049060853: 4,
#          1004647322310968: 1,
#          1004799230782204: 1,
#          1012839673718406: 997,
#          1017954922679517: 6,
#          1018519852607829: 1,
#          1019654191612071: 1,
#          1025876707956020: 1,
#          1026077759632952: 359,
#          1026137401571876: 1,
#          1027377272614773: 2,
#          1028781028604795: 44,
#          1030775109982217: 1,
#          1034625619399153: 291,
#          1040818444150354: 1,
#          1047248286288406: 45,
#          1048618420220267: 1,
#          1048763635720697: 1,
#          1050915593699495: 293,
#          1051178506740896: 266,
#          1052008034546732: 68,
#          1053268843098981: 1,
#          1059624469447602: 529,
#          1059829088794920: 5,
#          1066631039318186: 85,
#          1067106972354716: 701,
#          1068242160398055: 207,
#          1073629220097553: 676,
#          1083615462573354: 1,
#          1090714990440517: 265,
#          1097321699037769: 4,
#          1101907817173378: 1,
#          1108115801837396: 2,
#          1128518107621718: 10,
#          1128523976261306: 1,
#          1137662022945490: 37,
#          1138684448339312: 457,
#          1140187729516098: 1,
#          1143338053739359: 961,
#          1143593964734671: 1,
#          1143949129640741: 1,
#          1144399610472050: 4,
#          1145162787723854: 1,
#          1147170875616939: 1,
#          1147509017368847: 1,
#          1148244670915026: 1,
#          1150481971061132: 1,
#          1150582089135493: 176,
#          1151015415124728: 3,
#          1154532859875954: 1,
#          1156899474083695: 8,
#          1161996636662356: 95,
#          1174814305122529: 390,
#          1175124345944826: 10,
#          1184512454847840: 4,
#          1194669508142415: 38,
#          1195808031964813: 5,
#          1195856796150564: 1,
#          1196480138744965: 1,
#          3426158943927141: 328,
#          3427100731331602: 103,
#          3430550989487088: 97,
#          3431144404759479: 90,
#          3440841565190956: 975,
#          3448150058557478: 215,
#          3452150586150468: 4,
#          3452343433911782: 1,
#          3460041960278615: 40,
#          3462876459938792: 9,
#          3465186736362546: 2,
#          3468303372139808: 3,
#          3471444921572619: 1,
#          3472743674016439: 1,
#          3473673345860200: 5,
#          3474437463420896: 125,
#          3475769192145838: 22,
#          3476039922506696: 15,
#          3478140333182531: 1000,
#          3481085816424370: 1,
#          3481131589341063: 6,
#          3482656816690622: 15,
#          3492057734971657: 62,
#          3492223416806005: 25,
#          3498739961104962: 1,
#          3507249894453057: 31,
#          3508659623553104: 556,
#          3509111805535073: 185,
#          3511312798572723: 1,
#          3511386356373081: 1,
#          3511425652814191: 88,
#          3512985201812205: 693,
#          3515771167800793: 185,
#          3520168662282343: 1,
#          3521998078464046: 3,
#          3522674406285615: 24,
#          3522717225076755: 201,
#          3527958685366457: 42,
#          3540919442080496: 120,
#          3548981606329180: 5,
#          3549623450325173: 1,
#          3552027058570362: 21,
#          3552142160483231: 1,
#          3552668118543696: 5,
#          3555640999327427: 1,
#          3561250120505658: 2,
#          3565162666860050: 1,
#          3568678941832142: 76,
#          3582755896492537: 101,
#          3584893769867692: 1,
#          3586597297928792: 159,
#          3588296524989601: 1,
#          3590495050418816: 346,
#          3592596300190505: 1,
#          3593203247022180: 3,
#          3599042530200201: 443,
#          3601554954943923: 4,
#          3603532361145523: 9,
#          3609958519182151: 60,
#          3614707705149025: 5,
#          3615106254239030: 38,
#          3624444814627970: 3,
#          3627282875239810: 3,
#          3639568468122983: 2,
#          ...})

# %%
inverse_document_frequency[550680803298069]
# Out:
# 0.06935007813479324

# %%
sns.distplot(list(inverse_document_frequency.values()), kde=False)
# Out:
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fig, ax = plt.subplots()
ax.set(yscale='log')

sns.distplot(list(inverse_document_frequency.values()), kde=False)
# Out:
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/matplotlib/ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import pickle

# %%
mean_idf_per_cell = get_mean_idf_per_cell(siglist, inverse_document_frequency)

# %%
mean_idf_per_cell
# Out:
# 4.257475889366534

# %%
import numpy as np

# %%
sum(inverse_document_frequency.values())/len(inverse_document_frequency)
# Out:
# 6.616678327086432

# %% [markdown]
# ## Make new signatures not containing the hashes whose IDF is less than the mean IDF

# %%
s0 = siglist[0]
s1 = siglist[1]

# %%
s0
# Out:
# SourmashSignature('A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue:NA|cell_ontology_class:bladder_urothelial_cell|free_annotation:Luminal_bladder_epithelial_cell', 2da2310b)

# %%
s1
# Out:
# SourmashSignature('A1-MAA000779-3_11_M-1-1|tissue:Spleen|subtissue:NA|cell_ontology_class:B_cell|free_annotation:NA', a12e8f8a)

# %%
s0.jaccard(s1)
# Out:
# 0.03175723359209598

# %%
# %%file jaccard_utils.py

from joblib import Parallel, delayed
import itertools

def jaccard_sigs(i, j, siglist):
    return siglist[i].jaccard(siglist[j])

def jaccard_sigs_idf(i, j, siglist, idf, mean_idf_per_cell):
    i_hashes = filter_idf(siglist[i].get_mins(), inverse_document_frequency, mean_idf_per_cell)
    j_hashes = filter_idf(siglist[j].get_mins(), inverse_document_frequency, mean_idf_per_cell)
    return jacard(i_hashes, j_hashes)


def jaccard(sample1, sample2):
    """Jaccard similarity between two sets"""
    intersection = len(sample1.intersection(sample2))
    union = len(sample1.union(sample2))
    return intersection/union
# Out:
# Writing jaccard_utils.py

# %%
s0_hashes = set(s0.minhash.get_mins())
s1_hashes = set(s1.minhash.get_mins())


jaccard(s0_hashes, s1_hashes)
# Out:
# 0.03175723359209598

# %%
s0_hashes_idf = filter_idf(s0_hashes, inverse_document_frequency, mean_idf_per_cell)
s1_hashes_idf = filter_idf(s1_hashes, inverse_document_frequency, mean_idf_per_cell)

jaccard(s0_hashes_idf, s1_hashes_idf)
# Out:
# 0.0002236802863107665

# %%
len(siglist)
# Out:
# 1000

# %%
nrow = ncol = len(siglist)

values = np.zeros((nrow, ncol))
# %time names = [x.name() for x in siglist]
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 1.39 ms

# %%
names[:5]
# Out:
# ['A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue:NA|cell_ontology_class:bladder_urothelial_cell|free_annotation:Luminal_bladder_epithelial_cell',
#  'A1-MAA000779-3_11_M-1-1|tissue:Spleen|subtissue:NA|cell_ontology_class:B_cell|free_annotation:NA',
#  'A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:NA|cell_ontology_class:bladder_cell|free_annotation:Bladder_mesenchymal_cell',
#  'A10-B002775-3_39_F-1-1|tissue:Kidney|subtissue:NA|cell_ontology_class:endothelial_cell|free_annotation:NA',
#  'A10-MAA000559-3_8_M-1-1|tissue:Spleen|subtissue:NA|cell_ontology_class:B_cell|free_annotation:NA']

# %% [markdown]
# ## Make cell metadata

# %%
annotations = pd.read_csv('~/tabula-muris/00_data_ingest/18_global_annotation_csv/annotations_facs.csv', 
                          index_col='cell')
annotations.index = annotations.index.str.replace('.', '-')
annotations['sample_id'] = annotations.index
annotations = annotations.fillna("NA")
print(annotations.shape)
annotations.head()

# %%
cell_ids = [x.split('|')[0] for x in names]
print(len(cell_ids))
cell_metadata = annotations.loc[cell_ids]
print(cell_metadata.shape)
cell_metadata.head()

# %% [markdown]
# ## Compute similarity with and without IDF

# %%
np.vander?

# %%
# %%time

n_jobs = 32

values = Parallel(n_jobs=n_jobs)(delayed(jaccard_sigs)(i, j, siglist) 
                                 for i, j in itertools.product(range(nrow), range(ncol)))
# Out:
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# /home/olga/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning

# %%
compare_vanilla = pd.DataFrame(values, index=names, columns=names)
compare_vanilla.head()

# %%
# %%time

values_idf = Parallel(n_jobs=n_jobs)(delayed(jaccard_sigs_idf)(i, j, siglist, inverse_document_frequency, mean_idf_per_cell) 
                                 for i, j in itertools.product(range(nrow), range(ncol)))

# %%
compare_idf = pd.DataFrame(values_idf, index=names, columns=names)

# %%
# count_matrix = pd.DataFrame.from_records([s.minhash.get_mins(with_abundance=True) for s in siglist])
# print(count_matrix.shape)
# count_matrix.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-36-bc92bd7ee251> in <module>()
# ----> 1 count_matrix = pd.DataFrame.from_records([s.minhash.get_mins(with_abundance=True) for s in siglist])
#       2 print(count_matrix.shape)
#       3 count_matrix.head()
#
# ~/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/pandas/core/frame.py in from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    1267         else:
#    1268             arrays, arr_columns = _to_arrays(data, columns,
# -> 1269                                              coerce_float=coerce_float)
#    1270
#    1271             arr_columns = _ensure_index(arr_columns)
#
# ~/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7476     elif isinstance(data[0], collections.Mapping):
#    7477         return _list_of_dict_to_arrays(data, columns,
# -> 7478                                        coerce_float=coerce_float, dtype=dtype)
#    7479     elif isinstance(data[0], Series):
#    7480         return _list_of_series_to_arrays(data, columns,
#
# ~/miniconda3/envs/kmer-hashing/lib/python3.6/site-packages/pandas/core/frame.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#    7597     data = [(type(d) is dict) and d or dict(d) for d in data]
#    7598
# -> 7599     content = list(lib.dicts_to_array(data, list(columns)).T)
#    7600     return _convert_object_array(content, columns, dtype=dtype,
#    7601                                  coerce_float=coerce_float)
#
# pandas/_libs/lib.pyx in pandas._libs.lib.dicts_to_array()
#
# MemoryError:

# %%
range(2)

# %%
s.minhash.get_hashes() == s.minhash.get_mins()
# Out:
# True

# %% [markdown]
# ## Read annotations

# %%
annotations = pd.read_csv('/home/ubuntu/tabula-muris/00_data_ingest/18_global_annotation_csv/annotations_facs.csv', 
                          index_col='cell')
annotations.index = annotations.index.str.replace('.', '-')
annotations['sample_id'] = annotations.index
annotations = annotations.fillna("NA")
print(annotations.shape)
annotations.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4fc8476b2b70> in <module>()
# ----> 1 annotations = pd.read_csv('/home/ubuntu/tabula-muris/00_data_ingest/18_global_annotation_csv/annotations_facs.csv',
#       2                           index_col='cell')
#       3 annotations.index = annotations.index.str.replace('.', '-')
#       4 annotations['sample_id'] = annotations.index
#       5 annotations = annotations.fillna("NA")
#
# NameError: name 'pd' is not defined

# %%
tissues = 'Bladder', 'Kidney', 'Spleen', 'Liver', 'Pancreas'

annotations_subset = annotations.query('tissue in @tissues')
print(annotations_subset.shape)
annotations_subset.head()
# Out:
# (5872, 24)
#                       Neurog3>0_raw Neurog3>0_scaled      cell_ontology_class  \
# cell
# A1-B000610-3_56_F-1-1            NA               NA             bladder cell
# A1-B002764-3_38_F-1-1            NA               NA  bladder urothelial cell
# A1-B002771-3_39_F-1-1            NA               NA             bladder cell
# A1-D041914-3_8_M-1-1             NA               NA             bladder cell
# A1-D042253-3_9_M-1-1             NA               NA             bladder cell
#
#                       cell_ontology_id  cluster.ids  \
# cell
# A1-B000610-3_56_F-1-1       CL:1001319            5
# A1-B002764-3_38_F-1-1       CL:1001428            3
# A1-B002771-3_39_F-1-1       CL:1001319            5
# A1-D041914-3_8_M-1-1        CL:1001319            5
# A1-D042253-3_9_M-1-1        CL:1001319            2
#
#                                        free_annotation mouse.id mouse.sex  \
# cell
# A1-B000610-3_56_F-1-1         Bladder mesenchymal cell   3_56_F         F
# A1-B002764-3_38_F-1-1  Luminal bladder epithelial cell   3_38_F         F
# A1-B002771-3_39_F-1-1         Bladder mesenchymal cell   3_39_F         F
# A1-D041914-3_8_M-1-1          Bladder mesenchymal cell    3_8_M         M
# A1-D042253-3_9_M-1-1          Bladder mesenchymal cell    3_9_M         M
#
#                       plate.barcode subsetA          ...            \
# cell                                                 ...
# A1-B000610-3_56_F-1-1       B000610      NA          ...
# A1-B002764-3_38_F-1-1       B002764      NA          ...
# A1-B002771-3_39_F-1-1       B002771      NA          ...
# A1-D041914-3_8_M-1-1        D041914      NA          ...
# A1-D042253-3_9_M-1-1        D042253      NA          ...
#
#                       subsetC_cluster.ids subsetD subsetD_cluster.ids subsetE  \
# cell
# A1-B000610-3_56_F-1-1                  NA      NA                  NA      NA
# A1-B002764-3_38_F-1-1                  NA      NA                  NA      NA
# A1-B002771-3_39_F-1-1                  NA      NA                  NA      NA
# A1-D041914-3_8_M-1-1                   NA      NA                  NA      NA
# A1-D042253-3_9_M-1-1                   NA      NA                  NA      NA
#
#                       subsetE_cluster.ids subtissue   tissue tissue_tSNE_1  \
# cell
# A1-B000610-3_56_F-1-1                  NA        NA  Bladder     -7.182841
# A1-B002764-3_38_F-1-1                  NA        NA  Bladder      4.199059
# A1-B002771-3_39_F-1-1                  NA        NA  Bladder    -11.995435
# A1-D041914-3_8_M-1-1                   NA        NA  Bladder     -6.820022
# A1-D042253-3_9_M-1-1                   NA        NA  Bladder    -24.163538
#
#                       tissue_tSNE_2              sample_id
# cell
# A1-B000610-3_56_F-1-1    -10.895094  A1-B000610-3_56_F-1-1
# A1-B002764-3_38_F-1-1    -11.050240  A1-B002764-3_38_F-1-1
# A1-B002771-3_39_F-1-1     -7.325534  A1-B002771-3_39_F-1-1
# A1-D041914-3_8_M-1-1     -14.174246   A1-D041914-3_8_M-1-1
# A1-D042253-3_9_M-1-1      -7.499349   A1-D042253-3_9_M-1-1
#
# [5 rows x 24 columns]

# %%
annotations_subsampled = annotations_subset.groupby('tissue').apply(lambda x: x.sample(200, random_state=0))
print(annotations_subsampled.shape)
annotations_subsampled.head()
# Out:
# (1000, 24)
#                                  Neurog3>0_raw Neurog3>0_scaled  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1             NA               NA
#         H18-MAA000487-3_10_M-1-1            NA               NA
#         G22-D042253-3_9_M-1-1               NA               NA
#         A14-MAA000487-3_10_M-1-1            NA               NA
#         C6-D042253-3_9_M-1-1                NA               NA
#
#                                       cell_ontology_class cell_ontology_id  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1              bladder cell       CL:1001319
#         H18-MAA000487-3_10_M-1-1  bladder urothelial cell       CL:1001428
#         G22-D042253-3_9_M-1-1     bladder urothelial cell       CL:1001428
#         A14-MAA000487-3_10_M-1-1  bladder urothelial cell       CL:1001428
#         C6-D042253-3_9_M-1-1                 bladder cell       CL:1001319
#
#                                   cluster.ids  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1             0
#         H18-MAA000487-3_10_M-1-1            6
#         G22-D042253-3_9_M-1-1               1
#         A14-MAA000487-3_10_M-1-1            1
#         C6-D042253-3_9_M-1-1                2
#
#                                                   free_annotation mouse.id  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1          Bladder mesenchymal cell   3_10_M
#         H18-MAA000487-3_10_M-1-1    Basal bladder epithelial cell   3_10_M
#         G22-D042253-3_9_M-1-1     Luminal bladder epithelial cell    3_9_M
#         A14-MAA000487-3_10_M-1-1  Luminal bladder epithelial cell   3_10_M
#         C6-D042253-3_9_M-1-1             Bladder mesenchymal cell    3_9_M
#
#                                  mouse.sex plate.barcode subsetA  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1          M     MAA000487      NA
#         H18-MAA000487-3_10_M-1-1         M     MAA000487      NA
#         G22-D042253-3_9_M-1-1            M       D042253      NA
#         A14-MAA000487-3_10_M-1-1         M     MAA000487      NA
#         C6-D042253-3_9_M-1-1             M       D042253      NA
#
#                                             ...             \
# tissue  cell                                ...
# Bladder L4-MAA000487-3_10_M-1-1             ...
#         H18-MAA000487-3_10_M-1-1            ...
#         G22-D042253-3_9_M-1-1               ...
#         A14-MAA000487-3_10_M-1-1            ...
#         C6-D042253-3_9_M-1-1                ...
#
#                                  subsetC_cluster.ids subsetD  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1                   NA      NA
#         H18-MAA000487-3_10_M-1-1                  NA      NA
#         G22-D042253-3_9_M-1-1                     NA      NA
#         A14-MAA000487-3_10_M-1-1                  NA      NA
#         C6-D042253-3_9_M-1-1                      NA      NA
#
#                                  subsetD_cluster.ids subsetE  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1                   NA      NA
#         H18-MAA000487-3_10_M-1-1                  NA      NA
#         G22-D042253-3_9_M-1-1                     NA      NA
#         A14-MAA000487-3_10_M-1-1                  NA      NA
#         C6-D042253-3_9_M-1-1                      NA      NA
#
#                                  subsetE_cluster.ids subtissue   tissue  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1                   NA        NA  Bladder
#         H18-MAA000487-3_10_M-1-1                  NA        NA  Bladder
#         G22-D042253-3_9_M-1-1                     NA        NA  Bladder
#         A14-MAA000487-3_10_M-1-1                  NA        NA  Bladder
#         C6-D042253-3_9_M-1-1                      NA        NA  Bladder
#
#                                  tissue_tSNE_1 tissue_tSNE_2  \
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1      -3.848008    -31.627362
#         H18-MAA000487-3_10_M-1-1     -2.330604      8.687074
#         G22-D042253-3_9_M-1-1        18.170798      4.763290
#         A14-MAA000487-3_10_M-1-1      5.698090      8.262338
#         C6-D042253-3_9_M-1-1        -28.777886     -0.332360
#
#                                                  sample_id
# tissue  cell
# Bladder L4-MAA000487-3_10_M-1-1    L4-MAA000487-3_10_M-1-1
#         H18-MAA000487-3_10_M-1-1  H18-MAA000487-3_10_M-1-1
#         G22-D042253-3_9_M-1-1        G22-D042253-3_9_M-1-1
#         A14-MAA000487-3_10_M-1-1  A14-MAA000487-3_10_M-1-1
#         C6-D042253-3_9_M-1-1          C6-D042253-3_9_M-1-1
#
# [5 rows x 24 columns]

# %%
annotations_subsampled.groupby(['cell_ontology_class']).size()
# Out:
# cell_ontology_class
# B cell                                    163
# Kupffer cell                               14
# T cell                                     44
# bladder cell                              105
# bladder urothelial cell                    95
# endothelial cell                           64
# endothelial cell of hepatic sinusoid       49
# epithelial cell of proximal tubule         87
# hepatocyte                                117
# kidney collecting duct epithelial cell     34
# leukocyte                                  12
# macrophage                                 23
# natural killer cell                         8
# pancreatic A cell                          49
# pancreatic D cell                          17
# pancreatic PP cell                          6
# pancreatic acinar cell                     25
# pancreatic ductal cell                     15
# pancreatic stellate cell                    5
# type B pancreatic cell                     68
# dtype: int64

# %%
sample_id_with_annotation = \
    annotations['sample_id'] + '|tissue:' + annotations['tissue'] \
    + '|subtissue:' + annotations['subtissue'] \
    + '|cell_ontology_class:' + annotations['cell_ontology_class'] \
    + '|free_annotation:' + annotations['free_annotation']
sample_id_with_annotation = sample_id_with_annotation.str.replace(' ', '_')
sample_id_with_annotation.name = 'sample_id_with_annotation'
sample_id_with_annotation.head()
# Out:
# cell
# A1-B000610-3_56_F-1-1    A1-B000610-3_56_F-1-1|tissue:Bladder|subtissue...
# A1-B002764-3_38_F-1-1    A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue...
# A1-B002771-3_39_F-1-1    A1-B002771-3_39_F-1-1|tissue:Bladder|subtissue...
# A1-D041914-3_8_M-1-1     A1-D041914-3_8_M-1-1|tissue:Bladder|subtissue:...
# A1-D042253-3_9_M-1-1     A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# Name: sample_id_with_annotation, dtype: object

# %%
# ! aws s3 ls s3://olgabot-maca/facs/

# %%
# ! aws s3 ls s3://olgabot-maca/facs/

# %%
s3_prefix = 's3://czbiohub-maca/'

maca_aws = pd.read_table('s3://olgabot-maca/facs/aws_maca_remux_bytes_fastq.txt', sep='\s+', header=None, 
                         names=['date', 'time', 'filesize', 'suffix'])
maca_aws['megabytes'] = maca_aws['filesize']/1e6
maca_aws['novaseq_run'] = maca_aws['suffix'].str.extract('([AB]\d{5})')
maca_aws['novaseq_run_number'] = maca_aws['novaseq_run'].str.lstrip("AB")
maca_aws['sample_id'] = maca_aws['suffix'].str.split('/').str[-2]
maca_aws['sample_id_no_sample_number'] = maca_aws.sample_id.map(lambda x: '_'.join(x.split('_')[:3]))
maca_aws = maca_aws.join(sample_id_with_annotation, on='sample_id_no_sample_number')
maca_aws['full_s3_path'] = s3_prefix + maca_aws['suffix']
maca_aws['read'] = maca_aws['suffix'].str.extract('_(R[12])_')
print(maca_aws.shape)

maca_aws.head()
# Out:
# (263160, 12)
#          date      time  filesize  \
# 0  2017-10-31  19:17:18  52570660
# 1  2017-10-31  19:17:18  55481347
# 2  2017-10-31  19:14:53     53806
# 3  2017-10-31  19:14:53     54967
# 4  2017-10-31  19:14:53     36204
#
#                                               suffix  megabytes novaseq_run  \
# 0  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...  52.570660      A00111
# 1  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...  55.481347      A00111
# 2  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.053806      A00111
# 3  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.054967      A00111
# 4  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.036204      A00111
#
#   novaseq_run_number                  sample_id sample_id_no_sample_number  \
# 0              00111  A1-D041911-3_8_M-1-1_S128       A1-D041911-3_8_M-1-1
# 1              00111  A1-D041911-3_8_M-1-1_S128       A1-D041911-3_8_M-1-1
# 2              00111    A1-D041912-3_8_M-1-1_S1       A1-D041912-3_8_M-1-1
# 3              00111    A1-D041912-3_8_M-1-1_S1       A1-D041912-3_8_M-1-1
# 4              00111  A1-D041914-3_8_M-1-1_S269       A1-D041914-3_8_M-1-1
#
#                            sample_id_with_annotation  \
# 0  A1-D041911-3_8_M-1-1|tissue:Tongue|subtissue:N...
# 1  A1-D041911-3_8_M-1-1|tissue:Tongue|subtissue:N...
# 2  A1-D041912-3_8_M-1-1|tissue:Marrow|subtissue:G...
# 3  A1-D041912-3_8_M-1-1|tissue:Marrow|subtissue:G...
# 4  A1-D041914-3_8_M-1-1|tissue:Bladder|subtissue:...
#
#                                         full_s3_path read
# 0  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1
# 1  s3://czbiohub-maca/remux_data/170907_A00111_00...   R2
# 2  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1
# 3  s3://czbiohub-maca/remux_data/170907_A00111_00...   R2
# 4  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1

# %%
maca_aws_subsampled = maca_aws.query('sample_id_no_sample_number in @annotations_subsampled.sample_id')
print(maca_aws_subsampled.shape)
maca_aws_subsampled.head()
# Out:
# (4250, 12)
#           date      time  filesize  \
# 10  2017-10-31  19:32:42  25187121
# 11  2017-10-31  19:32:42  26936765
# 56  2017-10-31  19:14:53     45884
# 57  2017-10-31  19:14:53     46591
# 72  2017-10-31  19:15:21     53760
#
#                                                suffix  megabytes novaseq_run  \
# 10  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...  25.187121      A00111
# 11  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...  26.936765      A00111
# 56  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.045884      A00111
# 57  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.046591      A00111
# 72  remux_data/170907_A00111_0051_BH2HWLDMXX/rawda...   0.053760      A00111
#
#    novaseq_run_number                    sample_id sample_id_no_sample_number  \
# 10              00111     A1-D042253-3_9_M-1-1_S43       A1-D042253-3_9_M-1-1
# 11              00111     A1-D042253-3_9_M-1-1_S43       A1-D042253-3_9_M-1-1
# 56              00111   A10-D041914-3_8_M-1-1_S279      A10-D041914-3_8_M-1-1
# 57              00111   A10-D041914-3_8_M-1-1_S279      A10-D041914-3_8_M-1-1
# 72              00111  A10-MAA000559-3_8_M-1-1_S17    A10-MAA000559-3_8_M-1-1
#
#                             sample_id_with_annotation  \
# 10  A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# 11  A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# 56  A10-D041914-3_8_M-1-1|tissue:Bladder|subtissue...
# 57  A10-D041914-3_8_M-1-1|tissue:Bladder|subtissue...
# 72  A10-MAA000559-3_8_M-1-1|tissue:Spleen|subtissu...
#
#                                          full_s3_path read
# 10  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1
# 11  s3://czbiohub-maca/remux_data/170907_A00111_00...   R2
# 56  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1
# 57  s3://czbiohub-maca/remux_data/170907_A00111_00...   R2
# 72  s3://czbiohub-maca/remux_data/170907_A00111_00...   R1

# %%
samples = maca_aws_subsampled.groupby(['sample_id_no_sample_number', 'read']).apply(lambda x: '|'.join(x['full_s3_path'])).unstack()
samples = samples.join(sample_id_with_annotation)
samples = samples.rename(columns={'sample_id_with_annotation': 'name', "R1": "read1", "R2": "read2"})
print(samples.shape)
samples.head()
# Out:
# (1000, 3)
#                                                                         read1  \
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1        s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1     s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                         read2  \
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1        s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1     s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                          name
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue...
# A1-D042253-3_9_M-1-1        A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# A1-MAA000487-3_10_M-1-1     A1-MAA000487-3_10_M-1-1|tissue:Bladder|subtiss...
# A1-MAA000779-3_11_M-1-1     A1-MAA000779-3_11_M-1-1|tissue:Spleen|subtissu...
# A1-MAA100039-3_11_M-1-1     A1-MAA100039-3_11_M-1-1|tissue:Liver|subtissue...

# %%
! aws s3 ls s3://olgabot-maca/facs/
# Out:
#                            PRE merge_tabula_muris/
#                            PRE sourmash/
#                            PRE sourmash_compare/
#                            PRE sourmash_compare_combined/
#                            PRE sourmash_compare_no_track_abundance/
#                            PRE sourmash_compare_no_track_abundance_combined/
#                            PRE sourmash_compute_all/
#                            PRE sourmash_compute_all_b_cells/
#                            PRE sourmash_dna-only_trim=false_scaled=100/
#                            PRE sourmash_dna-only_trim=false_scaled=1000/
#                            PRE sourmash_dna-only_trim=false_scaled=1100/
#                            PRE sourmash_dna-only_trim=false_scaled=1200/
#                            PRE sourmash_dna-only_trim=false_scaled=1300/
#                            PRE sourmash_dna-only_trim=false_scaled=1400/
#                            PRE sourmash_dna-only_trim=false_scaled=1500/
#                            PRE sourmash_dna-only_trim=false_scaled=1600/
#                            PRE sourmash_dna-only_trim=false_scaled=1700/
#                            PRE sourmash_dna-only_trim=false_scaled=1800/
#                            PRE sourmash_dna-only_trim=false_scaled=1900/
#                            PRE sourmash_dna-only_trim=false_scaled=200/
#                            PRE sourmash_dna-only_trim=false_scaled=2000/
#                            PRE sourmash_dna-only_trim=false_scaled=2500/
#                            PRE sourmash_dna-only_trim=false_scaled=300/
#                            PRE sourmash_dna-only_trim=false_scaled=3000/
#                            PRE sourmash_dna-only_trim=false_scaled=3500/
#                            PRE sourmash_dna-only_trim=false_scaled=400/
#                            PRE sourmash_dna-only_trim=false_scaled=4000/
#                            PRE sourmash_dna-only_trim=false_scaled=4500/
#                            PRE sourmash_dna-only_trim=false_scaled=500/
#                            PRE sourmash_dna-only_trim=false_scaled=5000/
#                            PRE sourmash_dna-only_trim=false_scaled=600/
#                            PRE sourmash_dna-only_trim=false_scaled=700/
#                            PRE sourmash_dna-only_trim=false_scaled=800/
#                            PRE sourmash_dna-only_trim=false_scaled=900/
#                            PRE sourmash_dna-only_trim=true_scaled=100/
#                            PRE sourmash_dna-only_trim=true_scaled=1000/
#                            PRE sourmash_dna-only_trim=true_scaled=1000_test_subset/
#                            PRE sourmash_dna-only_trim=true_scaled=1100/
#                            PRE sourmash_dna-only_trim=true_scaled=1200/
#                            PRE sourmash_dna-only_trim=true_scaled=1300/
#                            PRE sourmash_dna-only_trim=true_scaled=1400/
#                            PRE sourmash_dna-only_trim=true_scaled=1500/
#                            PRE sourmash_dna-only_trim=true_scaled=1600/
#                            PRE sourmash_dna-only_trim=true_scaled=1700/
#                            PRE sourmash_dna-only_trim=true_scaled=1800/
#                            PRE sourmash_dna-only_trim=true_scaled=1900/
#                            PRE sourmash_dna-only_trim=true_scaled=200/
#                            PRE sourmash_dna-only_trim=true_scaled=2000/
#                            PRE sourmash_dna-only_trim=true_scaled=2500/
#                            PRE sourmash_dna-only_trim=true_scaled=300/
#                            PRE sourmash_dna-only_trim=true_scaled=3000/
#                            PRE sourmash_dna-only_trim=true_scaled=3500/
#                            PRE sourmash_dna-only_trim=true_scaled=400/
#                            PRE sourmash_dna-only_trim=true_scaled=4000/
#                            PRE sourmash_dna-only_trim=true_scaled=4500/
#                            PRE sourmash_dna-only_trim=true_scaled=500/
#                            PRE sourmash_dna-only_trim=true_scaled=5000/
#                            PRE sourmash_dna-only_trim=true_scaled=600/
#                            PRE sourmash_dna-only_trim=true_scaled=700/
#                            PRE sourmash_dna-only_trim=true_scaled=800/
#                            PRE sourmash_dna-only_trim=true_scaled=900/
#                            PRE sourmash_failed_samples/
#                            PRE sourmash_index/
#                            PRE sourmash_index_all/
#                            PRE sourmash_index_test/
#                            PRE sourmash_search/
#                            PRE sourmash_trim=true_scaled=100/
# 2018-06-11 18:16:08  133752351 aws_maca_remux.txt
# 2018-06-11 18:16:08  133752351 aws_maca_remux_bytes.txt
# 2018-06-11 18:16:11   39477616 aws_maca_remux_bytes_fastq.txt
# 2018-06-11 18:16:08   39477616 aws_maca_remux_fastq.txt
# 2018-06-11 18:16:08   16885502 fastqs.csv
# 2018-06-11 18:16:10   22255940 fastqs_sourmash.csv
# 2018-10-25 17:43:28  454820735 lung_cancer_v4_metadata.csv
# 2018-10-25 17:44:02  106599876 lung_cancer_v4_metadata.parquet
# 2018-10-01 18:21:23   49218255 signature-summaries.csv
# 2018-09-24 11:52:33   31907529 sourmash_compute_cpu_mem_time_profile.csv

# %%
# ! aws s3 ls s3://olgabot-maca/facs/sourmash/

# %%
samples['output'] = output_prefix +  samples.index + '.sig'
samples.head()
# Out:
#                                                                         read1  \
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1        s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1     s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                         read2  \
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1        s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1     s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1     s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                          name  \
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue...
# A1-D042253-3_9_M-1-1        A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# A1-MAA000487-3_10_M-1-1     A1-MAA000487-3_10_M-1-1|tissue:Bladder|subtiss...
# A1-MAA000779-3_11_M-1-1     A1-MAA000779-3_11_M-1-1|tissue:Spleen|subtissu...
# A1-MAA100039-3_11_M-1-1     A1-MAA100039-3_11_M-1-1|tissue:Liver|subtissue...
#
#                                                                        output
# sample_id_no_sample_number
# A1-B002764-3_38_F-1-1       s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-D042253-3_9_M-1-1        s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA000487-3_10_M-1-1     s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA000779-3_11_M-1-1     s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA100039-3_11_M-1-1     s3://olgabot-maca/facs/sourmash_compute_tissue...

# %%
samples['ksize'] = ksize
samples['num_hashes'] = num_hashes
samples['dna'] = dna
samples['protein'] = protein
samples.index.name = 'id'
samples['trim_low_abundance_kmers'] = False
samples.head()
# Out:
#                                                                      read1  \
# id
# A1-B002764-3_38_F-1-1    s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1     s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1  s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1  s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1  s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                      read2  \
# id
# A1-B002764-3_38_F-1-1    s3://czbiohub-maca/remux_data/170914_A00111_00...
# A1-D042253-3_9_M-1-1     s3://czbiohub-maca/remux_data/170907_A00111_00...
# A1-MAA000487-3_10_M-1-1  s3://czbiohub-maca/remux_data/170910_A00111_00...
# A1-MAA000779-3_11_M-1-1  s3://czbiohub-maca/remux_data/170928_A00111_00...
# A1-MAA100039-3_11_M-1-1  s3://czbiohub-maca/remux_data/170928_A00111_00...
#
#                                                                       name  \
# id
# A1-B002764-3_38_F-1-1    A1-B002764-3_38_F-1-1|tissue:Bladder|subtissue...
# A1-D042253-3_9_M-1-1     A1-D042253-3_9_M-1-1|tissue:Bladder|subtissue:...
# A1-MAA000487-3_10_M-1-1  A1-MAA000487-3_10_M-1-1|tissue:Bladder|subtiss...
# A1-MAA000779-3_11_M-1-1  A1-MAA000779-3_11_M-1-1|tissue:Spleen|subtissu...
# A1-MAA100039-3_11_M-1-1  A1-MAA100039-3_11_M-1-1|tissue:Liver|subtissue...
#
#                                                                     output  \
# id
# A1-B002764-3_38_F-1-1    s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-D042253-3_9_M-1-1     s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA000487-3_10_M-1-1  s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA000779-3_11_M-1-1  s3://olgabot-maca/facs/sourmash_compute_tissue...
# A1-MAA100039-3_11_M-1-1  s3://olgabot-maca/facs/sourmash_compute_tissue...
#
#                                ksize  num_hashes   dna  protein  \
# id
# A1-B002764-3_38_F-1-1    21,27,33,51     1000000  True     True
# A1-D042253-3_9_M-1-1     21,27,33,51     1000000  True     True
# A1-MAA000487-3_10_M-1-1  21,27,33,51     1000000  True     True
# A1-MAA000779-3_11_M-1-1  21,27,33,51     1000000  True     True
# A1-MAA100039-3_11_M-1-1  21,27,33,51     1000000  True     True
#
#                          trim_low_abundance_kmers
# id
# A1-B002764-3_38_F-1-1                       False
# A1-D042253-3_9_M-1-1                        False
# A1-MAA000487-3_10_M-1-1                     False
# A1-MAA000779-3_11_M-1-1                     False
# A1-MAA100039-3_11_M-1-1                     False
